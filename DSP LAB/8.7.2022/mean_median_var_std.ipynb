# %%
import pandas as pd
a=pd.Series([1,3,5,7,9])
print(a)
# Out:
# 0    1
# 1    3
# 2    5
# 3    7
# 4    9
# dtype: int64

# %%
print(a.mean())
print(a.var())
print(a.std())
print(a.median())
# Out:
# 5.0
# 10.0
# 3.1622776601683795
# 5.0

# %%
b=pd.Series([2,4,6,8,10])
print(b)
print(b.mean())
print(b.var())
print(b.std())
print(b.median())
# Out:
# 0     2
# 1     4
# 2     6
# 3     8
# 4    10
# dtype: int64
# 6.0
# 10.0
# 3.1622776601683795
# 6.0

# %%
c=pd.Series([3,6,9,12,15])
print(c)
print(c.mean())
print(c.var())
print(c.std())
print(c.median())
# Out:
# 0     3
# 1     6
# 2     9
# 3    12
# 4    15
# dtype: int64
# 9.0
# 22.5
# 4.743416490252569
# 9.0

# %%
d=pd.Series([5,10,15,20,25])
print(d)
print(d.mean())
print(d.var())
print(d.std())
print(d.median())
# Out:
# 0     5
# 1    10
# 2    15
# 3    20
# 4    25
# dtype: int64
# 15.0
# 62.5
# 7.905694150420948
# 15.0

# %%
import matplotlib.pyplot as plt
import pandas as pd
mylabels=["mean","std","var","median"]
e=[a.mean(),a.std(),a.var(),a.median()]
plt.pie(e,labels=mylabels)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
mylabels=["mean","std","var","median"]
f=[b.mean(),b.std(),b.var(),b.median()]
plt.pie(f,labels=mylabels)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
mylabels=["mean","std","var","median"]
g=[c.mean(),c.std(),c.var(),c.median()]
plt.pie(g,labels=mylabels)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
mylabels=["mean","std","var","median"]
h=[d.mean(),d.std(),d.var(),d.median()]
plt.pie(h,labels=mylabels,autopct='%1.1f%%')
plt.legend(title="statistics")
plt.show()

# %%
x=[a.mean(),b.mean(),c.mean(),d.mean()]
y=[a.std(),b.std(),c.std(),d.std()]
plt.bar(x,y)
plt.show()
